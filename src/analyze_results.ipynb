# %% [markdown]
# # Analyze results
#
# ## New version
# The new version is basically the same as the old version, just taking into account the new format of the CSV file.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re as regex
import seaborn as sns

from itertools import combinations
from scipy.stats import friedmanchisquare, wilcoxon
from sklearn.metrics import mean_squared_error, r2_score

# %%
# hard-coded variables for this analysis
# algorithms to consider
regressor_names = ["RandomForestRegressor", "XGBRegressor"]
regressor_names += ["PySRRegressor_default", "PySRRegressor_validation"]

# metric that will be used for the analysis
metric_function = mean_squared_error

# hard-coded name of the results file
#results_file = "../results_20260519_only_tree_models/openml_ctr23_statistics.csv"
#results_file = "../results_server_20260519/openml_ctr23_statistics.csv"
#results_file = "../results_20260519_default/openml_ctr23_statistics.csv"
#results_file = "../results_20260522_only_tree_models_5k_estimators/openml_ctr23_statistics.csv"
#results_file = "../results_20260605_task_361236/openml_ctr23_statistics.csv"
#results_file = "../results_20260605_task_361249/openml_ctr23_statistics.csv"
#results_file = "../results_20260605_task_361250/openml_ctr23_statistics.csv"
#results_file = "../results_20260622_hyperparameter_tuning_more_time/openml_ctr23_statistics.csv"

results_file = "../local_results/results_server_default_hyperparameters_20260519/openml_ctr23_statistics.csv"
#results_file = "../local_results/results_server_hyperparameter_tuning_20260519/openml_ctr23_statistics.csv"
#results_file = "../local_results/results_server_5hours/openml_ctr23_statistics.csv"

# additional part of the filename for each table, useful to differentiate results
additional_filename_part_tables = ""
additional_label_part_tables = ""
if "tuning" in results_file :
    additional_filename_part_tables = "_hyperparameter_tuning"
    additional_label_part_tables = "-hyperparameter-tuning"


results_filename = os.path.basename(results_file)
results_folder = os.path.dirname(results_file)

# let's create a subfolder for the LaTeX tables
tables_folder = os.path.join(results_folder, "latex_tables")
if not os.path.exists(tables_folder) :
    os.makedirs(tables_folder)

df = pd.read_csv(results_file)

# check the number of complete tasks
task_ids = df["task_id"].unique().tolist()
completed_task_ids = []

for t in task_ids :
    is_task_completed = True
    for r in regressor_names :
        if len(df[(df["task_id"] == t) & (df["regressor_name"] == r)]) != 10 :
            is_task_completed = False
            break

    if is_task_completed :
        completed_task_ids.append(t)

print("Number of completed tasks: " + str(len(completed_task_ids)) + " out of " + str(len(task_ids)))

# now, for each task, we can compute the mean and std of the R2 scores,
# and then we can perform a Friedman test to check if there are significant differences between the algorithms
statistics_dictionary = {
    'task_id' : [],
    'dataset_name' : [],
    'target_name': [], 
    'n_samples' : [],
    'n_features' : [], 
    'missing_data' : [], 
    'categorical_features' : [],
}
for r in regressor_names :
    statistics_dictionary["R2_" + r] = []
for r in regressor_names :
    statistics_dictionary["time_" + r] = []
    
for task_id in completed_task_ids :
    print("Task ID: " + str(task_id))
    df_task = df[df["task_id"] == task_id]

    # set up all the fields that do not depend on the regressor
    statistics_dictionary["task_id"].append(task_id)
    statistics_dictionary["dataset_name"].append(df_task["dataset_name"].iloc[0])
    statistics_dictionary["target_name"].append(df_task["target_name"].iloc[0])
    statistics_dictionary["n_samples"].append(df_task["n_samples"].iloc[0])
    statistics_dictionary["n_features"].append(df_task["n_features"].iloc[0])
    statistics_dictionary["missing_data"].append(df_task["missing_data"].iloc[0])
    statistics_dictionary["categorical_features"].append(df_task["categorical_features"].iloc[0])

    for regressor_name in regressor_names :
        df_regressor = df_task[df_task["regressor_name"] == regressor_name]
        
        r2_scores = df_regressor["R2"].tolist()
        time_scores = df_regressor["time_on_fold"].tolist()
        
        mean_r2 = np.mean(r2_scores)
        std_r2 = np.std(r2_scores)
        mean_time = np.mean(time_scores)
        std_time = np.std(time_scores)
        
        print("  " + regressor_name + ": mean R2 = " + str(mean_r2) + ", std R2 = " + str(std_r2))
        string_r2 = "$%.4f" % mean_r2 + " \pm " + "%.4f$" % std_r2
        statistics_dictionary["R2_" + regressor_name].append(string_r2)
        print("  " + regressor_name + ": mean time = " + str(mean_time) + ", std time = " + str(std_time))
        string_time = "$%.2f" % mean_time + " \pm " + "%.2f$" % std_time
        statistics_dictionary["time_" + regressor_name].append(string_time)

# save the dictionary to a dataframe, and then to a csv file
df_statistics = pd.DataFrame(statistics_dictionary)
df_statistics.to_csv(os.path.join(results_folder, "analysis_" + results_filename), index=False)

# after saving, we just sort it by task id
df_statistics.sort_values(by="task_id", inplace=True)
# Out:
# Number of completed tasks: 35 out of 35
# Task ID: 361618.0
#   RandomForestRegressor: mean R2 = -4.6275843437979045, std R2 = 8.430745447958666
#   RandomForestRegressor: mean time = 0.16342797279357907, std time = 0.011958113124810316
#   XGBRegressor: mean R2 = -11.493598337581505, std R2 = 16.62713320168572
#   XGBRegressor: mean time = 0.06723196506500238, std time = 0.0030128547563697343
#   PySRRegressor_default: mean R2 = -11.419430114707733, std R2 = 31.21886226325716
#   PySRRegressor_default: mean time = 73.19071640968323, std time = 4.265013196120225
#   PySRRegressor_validation: mean R2 = -0.2513711695987584, std R2 = 0.33840585587949384
#   PySRRegressor_validation: mean time = 73.19071640968323, std time = 4.265013196120225
# Task ID: 361619.0
#   RandomForestRegressor: mean R2 = 0.21580476757105832, std R2 = 0.15964249639457329
#   RandomForestRegressor: mean time = 0.1541845083236694, std time = 0.011804060608460638
# ...

# %%
# now, in this second part we are going to perform some operations on the DataFrame, reading CSV files
# with predictions, recomputing R2 values, and employing the Nadeau-Bengio test + Holm-Bonferroni correction
# to establish statistical significance with user-defined thresholds
significance_thresholds = [0.05, 0.01]
cell_highlight_color = 'e6ffe6' # a light green

regressor_names_in_tables = {
    'PySRRegressor_default' : 'Symbolic Regression',
    'PySRRegressor_validation' : 'Symbolic Regression',
    'RandomForestRegressor' : 'Random Forest',
    'XGBRegressor' : 'XGBoost',
}

# this is a version with acronyms
regressor_names_in_tables = {
    'PySRRegressor_default' : 'SR',
    'PySRRegressor_validation' : 'SR',
    'RandomForestRegressor' : 'RF',
    'XGBRegressor' : 'XGB',
}

# and a different highlight for each regressor
regressor_colors_good = {
    "PySRRegressor" : "ffd580",
    "RandomForestRegressor" : "e6ffe6",
    "XGBRegressor" : "aec2d6",
}

regressor_colors_bad = {
    "PySRRegressor" : "ad6f00",
    "RandomForestRegressor" : "00a800",
    "XGBRegressor" : "7393b3",
}

# import statistical tests from a local library
from common import compute_corrected_ttest, find_equivalent_best, holm_bonferroni, pairwise_tost_holm, pairwise_sbe_holm

# get the list of all CSV files in the results directory
task_prediction_files = [f for f in os.listdir(results_folder) if f.endswith("csv") and f.find("task") != -1]
print("Found %d task prediction files!" % len(task_prediction_files))
print(task_prediction_files)

# first step, let's just evaluate the PySRRegressor results, for a sanity check; we are also going to build
# a LaTeX table as we go
latex_table = r'\begin{table}[htb]' + "\n"
latex_table += r'\caption{Comparison in performance of model selection approaches (heuristic choice versus using a validation set) for Symbolic Regression using \texttt{PySR}. '
latex_table += r'If the difference is significant, the model with the best $R2$ score is highlighted in orange.'
latex_table += r'\label{table:comparison-model-selection' + additional_label_part_tables +'}}' + "\n"
latex_table += r'\centering' + "\n"
latex_table += r'\resizebox{0.99\textwidth}{!}{%' + "\n"
latex_table += r'\begin{tabular}{llccrr}' + "\n"
latex_table += r'\multirow{2}{*}{\textbf{Task ID}} & \multirow{2}{*}{\textbf{Dataset name}} & \multicolumn{2}{c}{\textbf{PySR R2, mean and std}} & \multicolumn{2}{c}{\textbf{Significant difference}}\\' + "\n"
latex_table += r' & & \textbf{Heuristic} & \textbf{Validation} & $p < 0.05$ & $p < 0.01$\\ \hline \hline' + "\n"

for index, row in df_statistics.iterrows() :
    task_id = row["task_id"]
    print("Now evaluating task %d..." % task_id)

    regressors_considered = ["PySRRegressor_default", "PySRRegressor_validation"]

    # compute the metric score for each fold, for each of the regressors considered;
    # at the beginning we were using only R2, so variable names still have that bias
    r2_scores = {k : [] for k in regressors_considered}
    for regressor_name in regressors_considered :
        # list all the files for this particular regressor and task
        task_files_regressor = [f for f in task_prediction_files if f.startswith(regressor_name) and f.find(str(int(task_id))) != -1]
        print("- Found %d task prediction files for regressor %s on task %d" % (len(task_files_regressor), regressor_name, task_id))

        for tf in task_files_regressor :
            df_pred = pd.read_csv(os.path.join(results_folder, tf))
            r2_scores[regressor_name].append(metric_function(df_pred["y_test"].values, df_pred["y_test_pred"].values))

    #print("R2 scores:", r2_scores)
    # now, let's check significance with the Nadeau-Bengio corrected test
    n_samples = int(str(row["n_samples"]).replace(",", ""))
    n_train = n_samples * 0.9
    n_test = n_samples * 0.1
    differences = np.array(r2_scores["PySRRegressor_default"]) - np.array(r2_scores["PySRRegressor_validation"])
    degrees_of_freedom = len(r2_scores["PySRRegressor_default"]) - 1
    t_stat, p_val = compute_corrected_ttest(differences, n_train, n_test)
    print("- p-value for the statistical test: %.4f" % p_val)

    significance = []
    for alpha in significance_thresholds :
        if p_val < alpha :
            print("- The two PySRRegressors are significantly different for p < %.2f" % alpha)
            significance.append(True)
        else :
            print("- The two PySRRegressors are not significantly different for p < %.2f" % alpha)
            significance.append(False)

    # fill in the LaTeX table row
    latex_table += str(int(task_id)) + r' & \texttt{' + str(row["dataset_name"].replace("_", r'\_')) + r'} & '
    
    # now, let's check if there is at least a significant difference
    latex_cell_color = ""
    if True in significance :
        latex_cell_color = r'\cellcolor[HTML]{' + regressor_colors_good["PySRRegressor"] + r'}'
    
    pysr_default_mean = float(row["R2_PySRRegressor_default"][1:].split(" ")[0])
    pysr_validation_mean = float(row["R2_PySRRegressor_validation"][1:].split(" ")[0]) 
    
    if pysr_default_mean > pysr_validation_mean :
        latex_table += latex_cell_color
    latex_table += row["R2_PySRRegressor_default"] + r' & '
    
    if pysr_validation_mean > pysr_default_mean :
        latex_table += latex_cell_color
    latex_table += row["R2_PySRRegressor_validation"]
    
    # wrap up the LaTeX table's row
    for s in significance :
        if s == True :
            latex_table += r' & Yes'
        else :
            latex_table += r' & No' 
    latex_table += r'\\' + "\n"

# wrap up the table
latex_table += r'\hline' + "\n"
latex_table += r'\end{tabular}%' + "\n"
latex_table += r'}' + "\n"
latex_table += r'\end{table}' + "\n"

# save the table
with open(os.path.join(tables_folder, "table_comparison_pysr" + additional_filename_part_tables + ".tex"), "w") as fp :
    fp.write(latex_table)
# Out:
# Found 1400 task prediction files!
# ...

# %%
# ok, and now another table! This time, same idea, but we compare different regressors
# we select all regressors, but for PySR we only use the version that selects the model using a validation set
regressors_considered = ["_".join(c.split("_")[1:]) for c in df_statistics.columns if c.startswith("R2") and not c.endswith("default")]
regressors_considered = sorted(regressors_considered)
print("Regressors considered:", regressors_considered)

# in parallel with the LaTeX table, let's also prepare a dictionary to later save as a CSV file;
# I need to look at the whole results also considering the new tests; Delta here is a hyperparameter
# used to check the regressors that are equivalent with the best
delta_equivalence = 0.05
dictionary_tost = {
    "task_id" : [],
    "dataset_name" : [],
    "R2_SR" : [],
    "R2_RF" : [],
    "R2_XGB" : [],
    "Significant best (0.05)" : [],
    "Significant best (0.01)" : [],
    "Significant worst (0.05)" : [],
    "Significant worst (0.01)" : [],
    "Equivalence (0.01)" : [],
    "Equivalence (0.05)" : [],
    "SBE 0.05 (SR vs RF)" : [],
    "SBE 0.05 (SR vs XGB)" : [],
    "SBE 0.05 (RF vs XGB)" : [],
    "SBE 0.01 (SR vs RF)" : [],
    "SBE 0.01 (SR vs XGB)" : [],
    "SBE 0.01 (RF vs XGB)" : [],
    "Equivalent (D=%.2f, p<0.05)" % delta_equivalence : [],
    "Equivalent (D=%.2f, p<0.01)" % delta_equivalence : [],
}

# ADDENDUM POST-REVIEW: we can add two columns, with "Equivalent Best" (p < 0.05) and (p < 0.01)
# just containing the list of regressors which are equivalent with the best
# Actually, we can just add a \dagger \ddagger symbol near the performance (see code below)

# an optional part of the caption
hyperparameters_string = "default"
if additional_filename_part_tables != "" :
    hyperparameters_string = "enhanced"

latex_table = r'\begin{table}[htb]' + "\n"
latex_table += r'\caption{Comparison of the regressors with ' + hyperparameters_string + r' hyperparameters. Regressors equivalent to the best according to a Nadeau-Bengio corrected TOST using a $\Delta=0.05$ are marked with $\dagger$ ($\alpha<0.05$) and $\ddagger$ ($\alpha<0.01$).'
latex_table += r'\label{table:comparison-regressors' + additional_label_part_tables + '}}' + "\n"
latex_table += r'\centering' + "\n"
latex_table += r'\resizebox{0.99\textwidth}{!}{%' + "\n"
latex_table += r'\begin{tabular}{llccccccc}' + "\n"
latex_table += r'\multirow{2}{*}{\textbf{Task ID}} & \multirow{2}{*}{\textbf{Dataset name}} & \multicolumn{3}{c}{\textbf{R2, mean and std}} & \multicolumn{2}{c}{\textbf{Significant best}} & \multicolumn{2}{c}{\textbf{Significant worst}}\\' + "\n"
latex_table += r' & & \textbf{Symbolic Regression} & \textbf{Random Forest} & \textbf{XGBoost} & $p < 0.05$ & $p < 0.01$ & $p < 0.05$ & $p < 0.01$\\ \hline \hline' + "\n"

for index, row in df_statistics.iterrows() :
    task_id = row["task_id"]
    print("Now evaluating task %d..." % task_id)

    # compute the R2 score for each fold, for each of the regressors considered
    r2_scores = {k : [] for k in regressors_considered}
    # also create a dictionary for the TOST test (this time, really using R2 and not just a 'metric' which could be MSE)
    tost_r2_scores = {k : [] for k in regressors_considered}
    for regressor_name in regressors_considered :
        # list all the files for this particular regressor and task
        task_files_regressor = [f for f in task_prediction_files if f.startswith(regressor_name) and f.find(str(int(task_id))) != -1]
        print("- Found %d task prediction files for regressor %s on task %d" % (len(task_files_regressor), regressor_name, task_id))

        for tf in task_files_regressor :
            df_pred = pd.read_csv(os.path.join(results_folder, tf))
            r2_scores[regressor_name].append(metric_function(df_pred["y_test"].values, df_pred["y_test_pred"].values))
            tost_r2_scores[regressor_name].append(r2_score(df_pred["y_test"].values, df_pred["y_test_pred"].values))

    # and now, we set up the pairwise tests
    n_samples = int(str(row["n_samples"]).replace(",", ""))
    n_train = n_samples * 0.9
    n_test = n_samples * 0.1
    degrees_of_freedom = len(r2_scores[regressors_considered[0]]) - 1
    
    # we use itertools.combinations, so that they are always in the same order
    # - PySRRegressor vs Random Forest
    # - PySRRegressor vs XGBoost
    # - XGBoost vs Random Forest
    p_values = []
    algorithm_combinations = combinations(regressors_considered, 2)
    for alg1, alg2 in algorithm_combinations :
        print("- Testing %s vs %s" % (alg1, alg2))
        differences = np.array(r2_scores[alg1]) - np.array(r2_scores[alg2])
        t_stat, p_val = compute_corrected_ttest(differences, n_train, n_test)
        p_values.append(p_val)

    print("- p-values:", p_values)

    # let's compute the Holm-Bonferroni correction
    holm_bonferroni_rejections = {alpha : [] for alpha in significance_thresholds}
    for alpha in significance_thresholds :
        holm_bonferroni_rejections[alpha] = holm_bonferroni(p_values, alpha=alpha)
    print("- Holm-Bonferroni rejection list:", holm_bonferroni_rejections)

    # last part, useful for later: recompute mean R2 values, sort from best to worst
    reverse_sorting = False
    if metric_function.__name__ == "r2_score" :
        reverse_sorting = True
    mean_r2_values = sorted([[np.mean(v), k] for k, v in r2_scores.items()], reverse=reverse_sorting)

    # another test: check if regressors are equivalent using Nadeau-Bengio corrected TOST,
    # using the special dictionary that we prepared before
    alphas = [0.05, 0.01]
    margin = 0.05
    for alpha in alphas :
        print("- Checking TOST equivalence for margin = %.2f and alpha = %.2f" % (margin, alpha))
        tost_results = pairwise_tost_holm(tost_r2_scores, margin, alpha=alpha)
        print("- TOST results:", tost_results["Is Equivalent"].values)
        if False in tost_results["Is Equivalent"].values :
            print("\t- The regressors are *not* equivalent for alpha = %.2f" % alpha)
            dictionary_tost["Equivalence (%s)" % alpha].append("No")
        else :
            print("\t- The regressors are equivalent for alpha = %.2f" % alpha)
            dictionary_tost["Equivalence (%s)" % alpha].append("Yes")

        # also find the Smallest Bound of Equivalence
        sbe_results = pairwise_sbe_holm(tost_r2_scores, alpha=alpha)
        print("- Smallest Bound of Equivalence results:", sbe_results)
        #print("\t- The smallest bound of equivalence is %.4f for alpha = %.2f" % (np.max(sbe_results["Smallest Bound of Equivalence"].values), alpha))

        # also compute non-inferiority
        df_non_inferiority_results = find_equivalent_best(tost_r2_scores, margin=delta_equivalence, alpha=alpha)
        df_mask = (df_non_inferiority_results["Status"]=="Empirical Best") | (df_non_inferiority_results["Status"]=="Equivalent")
        equivalence_list = sorted(df_non_inferiority_results[df_mask]["Model"].values)
        is_sr_equivalent = "No"
        if "PySRRegressor_validation" in equivalence_list :
            is_sr_equivalent = "Yes"

        dictionary_tost["Equivalent (D=%.2f, p<%s)" % (delta_equivalence, alpha)].append(equivalence_list)

        # now that we have the SBEs for each couple, we should reverse it from the sbe_results DataFrame to our dictionary
        sr_vs_rf = sbe_results[sbe_results["Pair"] == "PySRRegressor_validation vs RandomForestRegressor"]["SBE Holm (alpha=%s)" % alpha].values[0]
        sr_vs_xgb = sbe_results[sbe_results["Pair"] == "PySRRegressor_validation vs XGBRegressor"]["SBE Holm (alpha=%s)" % alpha].values[0]
        rf_vs_xgb = sbe_results[sbe_results["Pair"] == "RandomForestRegressor vs XGBRegressor"]["SBE Holm (alpha=%s)" % alpha].values[0]
        dictionary_tost["SBE %s (SR vs RF)" % alpha].append(sr_vs_rf)
        dictionary_tost["SBE %s (SR vs XGB)" % alpha].append(sr_vs_xgb)
        dictionary_tost["SBE %s (RF vs XGB)" % alpha].append(rf_vs_xgb)

    # we should now have everything to fill a row of the LaTeX table
    latex_table += str(int(task_id)) + r' & \texttt{' + str(row["dataset_name"].replace("_", r'\_')) + r'}'
    for regressor_name in regressors_considered :
        # check in the TOST dictionary if we need to add a special symbol
        additional_symbols = ""
        if regressor_name in dictionary_tost["Equivalent (D=%.2f, p<0.05)" % delta_equivalence][-1] :
            additional_symbols += r"\dagger"
        if  regressor_name in dictionary_tost["Equivalent (D=%.2f, p<0.01)" % delta_equivalence][-1] :
            additional_symbols += r"\ddagger"

        # now, we might need to manipulate the string
        table_field = row["R2_" + regressor_name]
        table_field = table_field[:-1] + additional_symbols + r"$"
        latex_table +=  r' & '+ table_field

    # also update dictionary
    dictionary_tost["task_id"].append(task_id)
    dictionary_tost["dataset_name"].append(row["dataset_name"])
    dictionary_tost["R2_SR"].append(row["R2_PySRRegressor_validation"])
    dictionary_tost["R2_RF"].append(row["R2_RandomForestRegressor"])
    dictionary_tost["R2_XGB"].append(row["R2_XGBRegressor"])

    # and now, some complex evaluations to fill in the last part of the row
    latex_row_best = ""
    latex_row_worst = ""
    for alpha in holm_bonferroni_rejections :
        
        number_of_true_values = len([h for h in holm_bonferroni_rejections[alpha] if h == True])
        best_regressor_name = "-"
        worst_regressor_name = "-"

        if number_of_true_values == 3 :
            # simplest case: all pairwise comparisons are significant
            # just pick the algorithm with the highest mean R2
            best_regressor_name = regressor_names_in_tables[mean_r2_values[0][1]]
            worst_regressor_name = regressor_names_in_tables[mean_r2_values[-1][1]]
        
        elif number_of_true_values == 2 :
            # another case: two values are True, so one algorithm is different
            print("- In this case, one of the regressors is significantly different")
            different_regressor = "PySRRegressor_validation"
            if holm_bonferroni_rejections[alpha][1] and holm_bonferroni_rejections[alpha][2] :
                different_regressor = "XGBRegressor"
            elif holm_bonferroni_rejections[alpha][0] and holm_bonferroni_rejections[alpha][2] :
                different_regressor = "RandomForestRegressor"
            
            # if the regressor which is different is also the one with the highest mean R2, we have a a winner!
            best_regressor_name = mean_r2_values[0][1]
            if different_regressor == best_regressor_name :
                print("- The different regressor was the best, %s" % best_regressor_name)
                best_regressor_name = regressor_names_in_tables[best_regressor_name]
            else :
                best_regressor_name = "-"
            
            worst_regressor_name = mean_r2_values[-1][1]
            if different_regressor ==  worst_regressor_name :
                print("- Interestingly the different regressor was significantly worse: %s" % different_regressor)
                worst_regressor_name = regressor_names_in_tables[worst_regressor_name]
            else :
                worst_regressor_name = "-"

        # also update the CSV
        dictionary_tost["Significant best (%s)" % alpha].append(best_regressor_name)
        dictionary_tost["Significant worst (%s)" % alpha].append(worst_regressor_name)
        
        # now, with the information available, start filling the row; we also add some colors, but
        # to that we need to invert the dictionary with regressor_name -> name to use inside tables
        table2algorithm = { v : k for k, v in regressor_names_in_tables.items()}
        #print(table2algorithm)
        
        cell_color_best = ""
        if best_regressor_name != "-" :
            color_code = regressor_colors_good[table2algorithm[best_regressor_name].split("_")[0]]
            cell_color_best = r'\cellcolor[HTML]{' + color_code + r'}'
        cell_color_worst = ""
        if worst_regressor_name != "-" :
            color_code = regressor_colors_bad[table2algorithm[worst_regressor_name].split("_")[0]]
            cell_color_worst = r'\cellcolor[HTML]{' + color_code + r'}'
            worst_regressor_name = r'\color{white}{' + worst_regressor_name + r'}'
            
        latex_row_best += r' & ' + cell_color_best + best_regressor_name
        latex_row_worst += r' & ' + cell_color_worst + worst_regressor_name

    # wrap up the row
    latex_table += latex_row_best + latex_row_worst
    latex_table += r'\\' + "\n"

# wrap up the table
latex_table += r'\hline' + "\n"
latex_table += r'\end{tabular}%' + "\n"
latex_table += r'}' + "\n"
latex_table += r'\end{table}' + "\n"

# save the table
with open(os.path.join(tables_folder, "table_comparison_regressors" + additional_filename_part_tables + ".tex"), "w") as fp :
    fp.write(latex_table)

# also save the dictionary as a CSV
df_tost_filename = os.path.join(tables_folder, "table_comparison_regressors" + additional_filename_part_tables + "_tost.csv")
df_tost = pd.DataFrame.from_dict(dictionary_tost)
print("Saving CSV file to \"%s\"..." % df_tost_filename)
df_tost.to_csv(df_tost_filename, index=False)
# Out:
# Regressors considered: ['PySRRegressor_validation', 'RandomForestRegressor', 'XGBRegressor']
# Now evaluating task 361234...
# - Found 10 task prediction files for regressor PySRRegressor_validation on task 361234
# - Found 10 task prediction files for regressor RandomForestRegressor on task 361234
# - Found 10 task prediction files for regressor XGBRegressor on task 361234
# - Testing PySRRegressor_validation vs RandomForestRegressor
# - Testing PySRRegressor_validation vs XGBRegressor
# - Testing RandomForestRegressor vs XGBRegressor
# - p-values: [np.float64(0.02623669516692218), np.float64(0.0010714704577307534), np.float64(0.001122760764208685)]
# - Holm-Bonferroni rejection list: {0.05: [True, True, True], 0.01: [False, True, True]}
# - Checking TOST equivalence for margin = 0.05 and alpha = 0.05
# - TOST results: [ True False False]
# 	- The regressors are *not* equivalent for alpha = 0.05
# ...

# %%
# this is just a hack to stop the execution when you run all cells, and avoid running the old code below
raise SystemExit("Stop right there!")
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: Stop right there!
# c:\Users\Alberto\anaconda3\envs\base-311\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# ## Memory consumption
#
# This is just to assess memory consumption, to answer a reviewer.

# %%
import numpy as np
import os
import pandas as pd

# %%
results_file = "../local_results/results_20260810_memory/openml_ctr23_statistics.csv"

df = pd.read_csv(results_file)

# get the different types of algorithms
algorithms = ["PySRRegressor_validation", "RandomForestRegressor", "XGBRegressor"]
tasks = df["task_id"].unique().tolist()

results_dict = {t : {a : 0.0 for a in algorithms} for t in tasks}

for task in tasks :
    print("Task ID: " + str(task))
    df_task = df[df["task_id"] == task]
    for algorithm in algorithms :
        df_algorithm = df_task[df_task["regressor_name"] == algorithm]
        mean_memory_usage = np.mean(df_algorithm["mean_memory_usage_MB"].values)
        results_dict[task][algorithm] = mean_memory_usage
        print("\t- \"%s\": %.2f MB" % (algorithm, mean_memory_usage))

most_memory_usage = {a : 0 for a in algorithms}
least_memory_usage = {a : 0 for a in algorithms}
memory_usage_differences = {a : [] for a in algorithms}
for task in tasks :
    for algorithm in algorithms :
        if results_dict[task][algorithm] == max(results_dict[task].values()) :
            most_memory_usage[algorithm] += 1
        if results_dict[task][algorithm] == min(results_dict[task].values()) :
            least_memory_usage[algorithm] += 1

        for a in algorithms :
            if a != algorithm :
                difference = results_dict[task][algorithm] - results_dict[task][a]
                if not np.isnan(difference) :
                    memory_usage_differences[algorithm].append(abs(difference))

for algorithm in algorithms :
    print("Algorithm \"%s\" used the most memory in %d tasks, and the least memory in %d tasks" % (algorithm, most_memory_usage[algorithm], least_memory_usage[algorithm]))
    print("Mean difference in memory usage: %.2f MB" % (np.mean(memory_usage_differences[algorithm])))
# Out:
# Task ID: 361618.0
# 	- "PySRRegressor_validation": 1107.37 MB
# 	- "RandomForestRegressor": 1142.94 MB
# 	- "XGBRegressor": 1235.74 MB
# Task ID: 361619.0
# 	- "PySRRegressor_validation": 1253.49 MB
# 	- "RandomForestRegressor": 1258.68 MB
# 	- "XGBRegressor": 1259.98 MB
# Task ID: 361617.0
# 	- "PySRRegressor_validation": 1269.20 MB
# 	- "RandomForestRegressor": 1287.46 MB
# 	- "XGBRegressor": 1288.12 MB
# Task ID: 361622.0
# 	- "PySRRegressor_validation": 1281.33 MB
# 	- "RandomForestRegressor": 1290.90 MB
# 	- "XGBRegressor": 1291.52 MB
# Task ID: 361621.0
# 	- "PySRRegressor_validation": 1113.41 MB
# 	- "RandomForestRegressor": 1103.26 MB
# 	- "XGBRegressor": 1188.05 MB
# Task ID: 361237.0
# 	- "PySRRegressor_validation": 1211.25 MB
# 	- "RandomForestRegressor": 1259.00 MB
# 	- "XGBRegressor": 1260.39 MB
# Task ID: 361243.0
# 	- "PySRRegressor_validation": 1265.74 MB
# 	- "RandomForestRegressor": 1273.38 MB
# 	- "XGBRegressor": 1290.23 MB
# Task ID: 361244.0
# ...

# %% [markdown]
# ## Old version
# Now that we have some results for the runs, we would like to know whether a regression algorithm is statistically better than the others, for each task. We will need the separate predictions for each task. ChatGPT tells me that, since all folds are the same for all algorithms, the best statistical test to compare them is a *paired* one. Since there are more than two algorithms, we should use the Friedman test, or so the mighty oracle says, followed by a Wilcoxon signed-rank test. Wow, that's a lot of important-sounding names

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re as regex
import seaborn as sns

from itertools import combinations
from scipy.stats import friedmanchisquare, wilcoxon
from sklearn.metrics import r2_score

# %%
# some hard-coded parameters for the analysis
task_details_file = "../results_20260504/openml_ctr23_statistics.csv"
results_folder = os.path.dirname(task_details_file)

significance_level = 0.05 # arbitrary, could also be 0.01

# %%
# first, let's list all *csv files in the results folder; and select the ones with the correct pattern
results_files = [
    f for f in os.listdir(results_folder) if regex.match(r"^\w+_task_\d+_fold_\d+\.csv$", f)
    and os.path.isfile(os.path.join(results_folder, f))
    and f.find("equation") == -1 # ignore files with "equation" in the name, as they contain the equations, not the results
]
print(f"Found {len(results_files)} results files: {results_files}")

# then, let's identify the unique tasks and algorithms from the filenames
tasks = set()
algorithms = set()
for file in results_files:
    match = regex.match(r"(\w+)_task_(\d+)_fold_(\d+)\.csv", file)
    if match:
        algorithm, task, _ = match.groups()
        algorithms.add(algorithm)
        tasks.add(task)

# sort the algorithms and the tasks
algorithms = sorted(list(algorithms))
tasks = sorted(list([int(t) for t in tasks]))

print(f"Found {len(tasks)} tasks: {tasks}")
print(f"Found {len(algorithms)} algorithms: {algorithms}")

# %%
# now, let's go task by task, and computer the R2 score for each algorithm from the predictions
results = {task: {alg: [] for alg in algorithms} for task in tasks}
r2_results = {task: {alg: {'mean': None, 'stdev' : None} for alg in algorithms} for task in tasks}
significant_best_algorithms = {task: {'best': None, 'non-separable' : []} for task in tasks}

for task in tasks:
    for algorithm in algorithms :
        # find the files for this task and algorithm
        task_files = [f for f in results_files if f.startswith(f"{algorithm}_task_{str(task)}_")]
        
        # read the predictions from each file and compute the R2 score
        for file in task_files :
            df = pd.read_csv(os.path.join(results_folder, file))
            column_true = [c for c in df.columns if c.endswith('_true')][0]
            column_pred = [c for c in df.columns if c.endswith('_pred')][0]
            
            # no error control, because we assume the files are well-formed
            r2 = r2_score(df[column_true], df[column_pred])
            results[task][algorithm].append(r2)

        r2_results[task][algorithm]['mean'] = np.mean(results[task][algorithm])
        r2_results[task][algorithm]['stdev'] = np.std(results[task][algorithm])

    # now that we have all the R2 scores for this task, we can compute the Friedman test
    r2_scores = [results[task][alg] for alg in algorithms]
    friedman_stat, p_value = friedmanchisquare(*r2_scores)

    if p_value < significance_level :
        print(f"Task {task}: Friedman test significant (p-value = {p_value:.4e})")
        
        # one (or more) values are the best! find the best mean R2 score
        best_alg = max(algorithms, key=lambda alg: r2_results[task][alg]['mean'])
        significant_best_algorithms[task]['best'] = best_alg

        # perform pairwise Wilcoxon signed-rank tests
        for alg1, alg2 in combinations(algorithms, 2):
            stat, p = wilcoxon(results[task][alg1], results[task][alg2])
            if p < significance_level:
                print(f"  {alg1} vs {alg2}: Wilcoxon test significant (p-value = {p:.4f})")
            else :
                print(f"  {alg1} vs {alg2}: Wilcoxon test NOT significant (p-value = {p:.4f})")
                significant_best_algorithms[task]['non-separable'].append((alg1, alg2))

    else :
        print(f"Task {task}: Friedman test not significant (p-value = {p_value:.4f})")
        for alg1, alg2 in combinations(algorithms, 2):
            significant_best_algorithms[task]['non-separable'].append((alg1, alg2))

print(significant_best_algorithms)

# %%
# a bit of debugging
for task in significant_best_algorithms.keys():
    print(f"Task {task}: best algorithm = {significant_best_algorithms[task]['best']}")
    if significant_best_algorithms[task]['non-separable']:
        print(f"  Non-separable algorithms: {', '.join([f'{alg1} vs {alg2}' for alg1, alg2 in significant_best_algorithms[task]['non-separable']])}")
    else:
        print("  All algorithms are separable")

# %%
# ok, but actually what about a nice Excel spreadsheet?
# first, let's read a file with all the task details
df_tasks = pd.read_csv(task_details_file)

# and now we are going to create a dictionary that will be later converted to a DataFrame
results_dict = {
    'task_id' : [],
    'dataset_name' : [],
    'target_name' : [],
    'n_samples' : [],
    'n_features' : [],
    'missing_data' : [],
    'categorical_features' : [],
    'R2_PySRRegressor' : [],
    'R2_RandomForestRegressor' : [],
    'R2_XGBRegressor' : [],
}

# copy all the other columns from the df_tasks DataFrame
for column in results_dict.keys() :
    if not column.startswith('R2_') :
        results_dict[column] = df_tasks[column].tolist()

# rewrite the R2 scores for each algorithm
for task in tasks:
    for algorithm in algorithms:

        results_dict[f'R2_{algorithm}'].append("%.4f \pm~%.4f" %
                                               (r2_results[task][algorithm]['mean'], r2_results[task][algorithm]['stdev']))

# a little bit of debugging here
#for key, value in results_dict.items():
#    print("key \"%s\" : %d" % (key, len(value)))  
# and now we can create a DataFrame from the dictionary
df_results = pd.DataFrame(results_dict)

# color the cells, marking the significant best algorithms for each task
def highlight_best_algorithms_new(row) :
    task = row['task_id']
    best_algorithm = significant_best_algorithms[task]['best']
    non_separable_algorithms = significant_best_algorithms[task]['non-separable']
    # col[3:] is used to skip the 'R2_' prefix, so it's the name of the algorithm
    # #e6ffe6 is a very light green color
    styles = []
    for col in row.index:
        if col.startswith('R2_') :
            alg = col[3:]  # get the algorithm name without 'R2_'
            cell_style = '' # default cell style
            
            # check all the possibilities for different cell style
            if alg == best_algorithm :
                cell_style = 'background-color: #e6ffe6'
            elif any(alg in pair for pair in non_separable_algorithms) :
                # check where the algorithm appears in the non-separable list
                cell_style = 'background-color: #ffffe0' # default: light yellow
                for pair in non_separable_algorithms :
                    if alg in pair :
                        if best_algorithm in pair :
                            cell_style = 'background-color: #e6ffe6' # green if is part of a pair with the best algorithm
            
            styles.append(cell_style)
        else :
            styles.append('')
    
    print(styles)
    return styles

def highlight_best_algorithms(row):
    task = row['task_id']
    best_algorithm = significant_best_algorithms[task]['best']
    non_separable_algorithms = significant_best_algorithms[task]['non-separable']
    
    styles = [
        'background-color: #e6ffe6' if col.startswith('R2_') and col[3:] == best_algorithm else
        '' for col in row.index
    ]
    print(styles)
    return styles


#print(significant_best_algorithms)

# apply the highlighting function to the R2 columns
df_results = df_results.style.apply(highlight_best_algorithms_new, axis=1)

# finally, save to Excel
file_name_results = "analysis_" + os.path.basename(task_details_file).replace(".csv", ".xlsx")
file_name_results = os.path.join(results_folder, file_name_results)
df_results.to_excel(file_name_results, index=False)

# %%
# we employ another dictionary to store how many times each algorithm
# was the best or tied for the best
algorithm_counts = {algorithm : {'best': 0, 'tied_for_best': 0} for algorithm in algorithms}

for task in significant_best_algorithms.keys():
    best_alg = significant_best_algorithms[task]['best']
    
    if best_alg is not None:
        algorithm_counts[best_alg]['best'] += 1
    else :
        algs_tied_for_best = set()
        for alg1, alg2 in significant_best_algorithms[task]['non-separable']:
            algs_tied_for_best.add(alg1)
            algs_tied_for_best.add(alg2)
        
        for alg in algs_tied_for_best:
            algorithm_counts[alg]['tied_for_best'] += 1

print("Algorithm counts:")
for algorithm, counts in algorithm_counts.items():
    print(f"  {algorithm}: Best = {counts['best']}, Tied for Best = {counts['tied_for_best']}")

print(significant_best_algorithms)
