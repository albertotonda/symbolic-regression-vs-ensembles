# %% [markdown]
# # Analyze results
# Now that we have some results for the runs, we would like to know whether a regression algorithm is statistically better than the others, for each task. We will need the separate predictions for each task. ChatGPT tells me that, since all folds are the same for all algorithms, the best statistical test to compare them is a *paired* one. Since there are more than two algorithms, we should use the Friedman test, or so the mighty oracle says, followed by a Wilcoxon signed-rank test. Wow, that's a lot of important-sounding names

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re as regex
import seaborn as sns

from itertools import combinations
from scipy.stats import friedmanchisquare, wilcoxon
from sklearn.metrics import r2_score

# %%
# some hard-coded parameters for the analysis
results_folder = "../results_server" # VSCODE likes to use the root folder as the working directory, but NOT for notebooks
task_details_file = "../results_server/20250722_openml_ctr23_statistics_mu50.csv"

significance_level = 0.05 # arbitrary, could also be 0.01

# %%
# first, let's list all *csv files in the results folder; and select the ones with the correct pattern
results_files = [
    f for f in os.listdir(results_folder) if regex.match(r"^\w+_task_\d+_fold_\d+\.csv$", f)
    and os.path.isfile(os.path.join(results_folder, f))
]
print(f"Found {len(results_files)} results files: {results_files}")

# then, let's identify the unique tasks and algorithms from the filenames
tasks = set()
algorithms = set()
for file in results_files:
    match = regex.match(r"(\w+)_task_(\d+)_fold_(\d+)\.csv", file)
    if match:
        algorithm, task, _ = match.groups()
        algorithms.add(algorithm)
        tasks.add(task)

# sort the algorithms and the tasks
algorithms = sorted(list(algorithms))
tasks = sorted(list([int(t) for t in tasks]))

print(f"Found {len(tasks)} tasks: {tasks}")
print(f"Found {len(algorithms)} algorithms: {algorithms}")
# Out:
# Found 1050 results files: ['PySRRegressor_task_361234_fold_0.csv', 'PySRRegressor_task_361234_fold_1.csv', 'PySRRegressor_task_361234_fold_2.csv', 'PySRRegressor_task_361234_fold_3.csv', 'PySRRegressor_task_361234_fold_4.csv', 'PySRRegressor_task_361234_fold_5.csv', 'PySRRegressor_task_361234_fold_6.csv', 'PySRRegressor_task_361234_fold_7.csv', 'PySRRegressor_task_361234_fold_8.csv', 'PySRRegressor_task_361234_fold_9.csv', 'PySRRegressor_task_361235_fold_0.csv', 'PySRRegressor_task_361235_fold_1.csv', 'PySRRegressor_task_361235_fold_2.csv', 'PySRRegressor_task_361235_fold_3.csv', 'PySRRegressor_task_361235_fold_4.csv', 'PySRRegressor_task_361235_fold_5.csv', 'PySRRegressor_task_361235_fold_6.csv', 'PySRRegressor_task_361235_fold_7.csv', 'PySRRegressor_task_361235_fold_8.csv', 'PySRRegressor_task_361235_fold_9.csv', 'PySRRegressor_task_361236_fold_0.csv', 'PySRRegressor_task_361236_fold_1.csv', 'PySRRegressor_task_361236_fold_2.csv', 'PySRRegressor_task_361236_fold_3.csv', 'PySRRegressor_task_361236_fold_4.csv', 'PySRRegressor_task_361236_fold_5.csv', 'PySRRegressor_task_361236_fold_6.csv', 'PySRRegressor_task_361236_fold_7.csv', 'PySRRegressor_task_361236_fold_8.csv', 'PySRRegressor_task_361236_fold_9.csv', 'PySRRegressor_task_361237_fold_0.csv', 'PySRRegressor_task_361237_fold_1.csv', 'PySRRegressor_task_361237_fold_2.csv', 'PySRRegressor_task_361237_fold_3.csv', 'PySRRegressor_task_361237_fold_4.csv', 'PySRRegressor_task_361237_fold_5.csv', 'PySRRegressor_task_361237_fold_6.csv', 'PySRRegressor_task_361237_fold_7.csv', 'PySRRegressor_task_361237_fold_8.csv', 'PySRRegressor_task_361237_fold_9.csv', 'PySRRegressor_task_361241_fold_0.csv', 'PySRRegressor_task_361241_fold_1.csv', 'PySRRegressor_task_361241_fold_2.csv', 'PySRRegressor_task_361241_fold_3.csv', 'PySRRegressor_task_361241_fold_4.csv', 'PySRRegressor_task_361241_fold_5.csv', 'PySRRegressor_task_361241_fold_6.csv', 'PySRRegressor_task_361241_fold_7.csv', 'PySRRegressor_task_361241_fold_8.csv', 'PySRRegressor_task_361241_fold_9.csv', 'PySRRegressor_task_361242_fold_0.csv', 'PySRRegressor_task_361242_fold_1.csv', 'PySRRegressor_task_361242_fold_2.csv', 'PySRRegressor_task_361242_fold_3.csv', 'PySRRegressor_task_361242_fold_4.csv', 'PySRRegressor_task_361242_fold_5.csv', 'PySRRegressor_task_361242_fold_6.csv', 'PySRRegressor_task_361242_fold_7.csv', 'PySRRegressor_task_361242_fold_8.csv', 'PySRRegressor_task_361242_fold_9.csv', 'PySRRegressor_task_361243_fold_0.csv', 'PySRRegressor_task_361243_fold_1.csv', 'PySRRegressor_task_361243_fold_2.csv', 'PySRRegressor_task_361243_fold_3.csv', 'PySRRegressor_task_361243_fold_4.csv', 'PySRRegressor_task_361243_fold_5.csv', 'PySRRegressor_task_361243_fold_6.csv', 'PySRRegressor_task_361243_fold_7.csv', 'PySRRegressor_task_361243_fold_8.csv', 'PySRRegressor_task_361243_fold_9.csv', 'PySRRegressor_task_361244_fold_0.csv', 'PySRRegressor_task_361244_fold_1.csv', 'PySRRegressor_task_361244_fold_2.csv', 'PySRRegressor_task_361244_fold_3.csv', 'PySRRegressor_task_361244_fold_4.csv', 'PySRRegressor_task_361244_fold_5.csv', 'PySRRegressor_task_361244_fold_6.csv', 'PySRRegressor_task_361244_fold_7.csv', 'PySRRegressor_task_361244_fold_8.csv', 'PySRRegressor_task_361244_fold_9.csv', 'PySRRegressor_task_361247_fold_0.csv', 'PySRRegressor_task_361247_fold_1.csv', 'PySRRegressor_task_361247_fold_2.csv', 'PySRRegressor_task_361247_fold_3.csv', 'PySRRegressor_task_361247_fold_4.csv', 'PySRRegressor_task_361247_fold_5.csv', 'PySRRegressor_task_361247_fold_6.csv', 'PySRRegressor_task_361247_fold_7.csv', 'PySRRegressor_task_361247_fold_8.csv', 'PySRRegressor_task_361247_fold_9.csv', 'PySRRegressor_task_361249_fold_0.csv', 'PySRRegressor_task_361249_fold_1.csv', 'PySRRegressor_task_361249_fold_2.csv', 'PySRRegressor_task_361249_fold_3.csv', 'PySRRegressor_task_361249_fold_4.csv', 'PySRRegressor_task_361249_fold_5.csv', 'PySRRegressor_task_361249_fold_6.csv', 'PySRRegressor_task_361249_fold_7.csv', 'PySRRegressor_task_361249_fold_8.csv', 'PySRRegresso ...
# Found 35 tasks: [361234, 361235, 361236, 361237, 361241, 361242, 361243, 361244, 361247, 361249, 361250, 361251, 361252, 361253, 361254, 361255, 361256, 361257, 361258, 361259, 361260, 361261, 361264, 361266, 361267, 361268, 361269, 361272, 361616, 361617, 361618, 361619, 361621, 361622, 361623]
# Found 3 algorithms: ['PySRRegressor', 'RandomForestRegressor', 'XGBRegressor']

# %%
# now, let's go task by task, and computer the R2 score for each algorithm from the predictions
results = {task: {alg: [] for alg in algorithms} for task in tasks}
r2_results = {task: {alg: {'mean': None, 'stdev' : None} for alg in algorithms} for task in tasks}
significant_best_algorithms = {task: [] for task in tasks}

for task in tasks:
    for algorithm in algorithms :
        # find the files for this task and algorithm
        task_files = [f for f in results_files if f.startswith(f"{algorithm}_task_{str(task)}_")]
        
        # read the predictions from each file and compute the R2 score
        for file in task_files :
            df = pd.read_csv(os.path.join(results_folder, file))
            column_true = [c for c in df.columns if c.endswith('_true')][0]
            column_pred = [c for c in df.columns if c.endswith('_pred')][0]
            
            # no error control, because we assume the files are well-formed
            r2 = r2_score(df[column_true], df[column_pred])
            results[task][algorithm].append(r2)

        r2_results[task][algorithm]['mean'] = np.mean(results[task][algorithm])
        r2_results[task][algorithm]['stdev'] = np.std(results[task][algorithm])

    # now that we have all the R2 scores for this task, we can compute the Friedman test
    r2_scores = [results[task][alg] for alg in algorithms]
    friedman_stat, p_value = friedmanchisquare(*r2_scores)

    if p_value < significance_level :
        print(f"Task {task}: Friedman test significant (p-value = {p_value:.4e})")
        
        # perform pairwise Wilcoxon signed-rank tests
        for alg1, alg2 in combinations(algorithms, 2):
            stat, p = wilcoxon(results[task][alg1], results[task][alg2])
            if p < significance_level:
                print(f"  {alg1} vs {alg2}: Wilcoxon test significant (p-value = {p:.4f})")
                if r2_results[task][alg1]['mean'] > r2_results[task][alg2]['mean'] :
                    significant_best_algorithms[task].append(alg1)
                elif r2_results[task][alg1]['mean'] < r2_results[task][alg2]['mean'] :
                    significant_best_algorithms[task].append(alg2)
            else :
                print(f"  {alg1} vs {alg2}: Wilcoxon test NOT significant (p-value = {p:.4f})")
                if max([r2_results[task][a]['mean'] for a in algorithms]) == r2_results[task][alg1]['mean'] or \
                     max([r2_results[task][a]['mean'] for a in algorithms]) == r2_results[task][alg2]['mean'] :
                    significant_best_algorithms[task].append(alg1)
                    significant_best_algorithms[task].append(alg2)
        # remove duplicates
        significant_best_algorithms[task] = list(set(significant_best_algorithms[task]))
    else :
        print(f"Task {task}: Friedman test not significant (p-value = {p_value:.4f})")
# Out:
# Task 361234: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0059)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361235: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0039)
# Task 361236: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361237: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361241: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361242: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0039)
# Task 361243: Friedman test significant (p-value = 5.5166e-03)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.4316)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.1055)
# Task 361244: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361247: Friedman test significant (p-value = 3.7074e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.1055)
# Task 361249: Friedman test significant (p-value = 2.2487e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0098)
# Task 361250: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0039)
# Task 361251: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361252: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361253: Friedman test significant (p-value = 2.2487e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test NOT significant (p-value = 0.1055)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361254: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361255: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0039)
# Task 361256: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0039)
# Task 361257: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361258: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361259: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361260: Friedman test significant (p-value = 3.7074e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.1934)
# Task 361261: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0059)
# Task 361264: Friedman test significant (p-value = 2.7324e-02)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test NOT significant (p-value = 0.2324)
#   PySRRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.2754)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0371)
# Task 361266: Friedman test significant (p-value = 5.5308e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.4922)
# Task 361267: Friedman test significant (p-value = 1.2309e-03)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0039)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.1055)
# Task 361268: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361269: Friedman test significant (p-value = 4.5400e-05)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361272: Friedman test significant (p-value = 5.0045e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test NOT significant (p-value = 0.3223)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361616: Friedman test significant (p-value = 2.2487e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test NOT significant (p-value = 0.2754)
# Task 361617: Friedman test significant (p-value = 1.1167e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0020)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0039)
# Task 361618: Friedman test significant (p-value = 3.0354e-04)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test significant (p-value = 0.0059)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0273)
# Task 361619: Friedman test significant (p-value = 2.4724e-02)
#   PySRRegressor vs RandomForestRegressor: Wilcoxon test NOT significant (p-value = 0.6953)
#   PySRRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0371)
#   RandomForestRegressor vs XGBRegressor: Wilcoxon test significant (p-value = 0.0020)
# Task 361621: Friedman test not significant (p-value = 0.1225)
# Task 361622: Friedman test not significant (p-value = 0.0608)
# Task 361623: Friedman test not significant (p-value = 0.0821)

# %%
# and now we can create a latex table with the results, highlighting the significant best algorithms
print("\n\\begin{tabular}{|c|c|c|c|}")
print("\\hline")
print("Task & Algorithm & Mean R2 & Stdev R2 \\\\")
print("\\hline")
for task in tasks:
    for algorithm in algorithms:
        mean_r2 = r2_results[task][algorithm]['mean']
        stdev_r2 = r2_results[task][algorithm]['stdev']
        if algorithm in significant_best_algorithms[task]:
            print(f"{task} & {algorithm} & \\textbf{{{mean_r2:.4f}}}* & \\textbf{stdev_r2:.4f} \\\\")
        else:
            print(f"{task} & {algorithm} & {mean_r2:.4f} & {stdev_r2:.4f} \\\\")
    print("\\hline")
print("\\hline")
print("\\end{tabular}")
# Out:
# \begin{tabular}{|c|c|c|c|}
# \hline
# Task & Algorithm & Mean R2 & Stdev R2 \\
# \hline
# 361234 & PySRRegressor & \textbf{0.5698}* & \textbf0.0224 \\
# 361234 & RandomForestRegressor & \textbf{0.5490}* & \textbf0.0173 \\
# 361234 & XGBRegressor & 0.4586 & 0.0264 \\
# \hline
# 361235 & PySRRegressor & 0.6581 & 0.0506 \\
# 361235 & RandomForestRegressor & \textbf{0.9415}* & \textbf0.0125 \\
# 361235 & XGBRegressor & \textbf{0.9608}* & \textbf0.0099 \\
# \hline
# 361236 & PySRRegressor & 0.8824 & 0.0289 \\
# 361236 & RandomForestRegressor & \textbf{0.9946}* & \textbf0.0016 \\
# 361236 & XGBRegressor & \textbf{0.9992}* & \textbf0.0002 \\
# \hline
# 361237 & PySRRegressor & 0.8301 & 0.0335 \\
# 361237 & RandomForestRegressor & \textbf{0.9150}* & \textbf0.0272 \\
# 361237 & XGBRegressor & \textbf{0.9365}* & \textbf0.0235 \\
# \hline
# 361241 & PySRRegressor & 0.3276 & 0.0142 \\
# 361241 & RandomForestRegressor & \textbf{0.6819}* & \textbf0.0045 \\
# 361241 & XGBRegressor & \textbf{0.6474}* & \textbf0.0042 \\
# \hline
# 361242 & PySRRegressor & 0.7177 & 0.0182 \\
# 361242 & RandomForestRegressor & \textbf{0.9273}* & \textbf0.0065 \\
# 361242 & XGBRegressor & \textbf{0.9203}* & \textbf0.0073 \\
# \hline
# 361243 & PySRRegressor & 0.2139 & 0.0402 \\
# 361243 & RandomForestRegressor & \textbf{0.2699}* & \textbf0.0599 \\
# 361243 & XGBRegressor & \textbf{0.2310}* & \textbf0.1065 \\
# \hline
# 361244 & PySRRegressor & \textbf{0.1738}* & \textbf0.0353 \\
# 361244 & RandomForestRegressor & \textbf{-0.1684}* & \textbf0.1955 \\
# 361244 & XGBRegressor & -0.4057 & 0.3650 \\
# \hline
# 361247 & PySRRegressor & 0.9124 & 0.0234 \\
# 361247 & RandomForestRegressor & \textbf{0.9965}* & \textbf0.0007 \\
# 361247 & XGBRegressor & \textbf{0.9961}* & \textbf0.0004 \\
# \hline
# 361249 & PySRRegressor & 0.3037 & 0.0299 \\
# 361249 & RandomForestRegressor & \textbf{0.5453}* & \textbf0.0407 \\
# 361249 & XGBRegressor & \textbf{0.5036}* & \textbf0.0439 \\
# \hline
# 361250 & PySRRegressor & 0.3898 & 0.0273 \\
# 361250 & RandomForestRegressor & \textbf{0.5138}* & \textbf0.0576 \\
# 361250 & XGBRegressor & \textbf{0.4621}* & \textbf0.0742 \\
# \hline
# 361251 & PySRRegressor & 0.7354 & 0.0254 \\
# 361251 & RandomForestRegressor & \textbf{0.9010}* & \textbf0.0067 \\
# 361251 & XGBRegressor & \textbf{0.9372}* & \textbf0.0048 \\
# \hline
# 361252 & PySRRegressor & 0.8375 & 0.0272 \\
# 361252 & RandomForestRegressor & \textbf{0.9928}* & \textbf0.0012 \\
# 361252 & XGBRegressor & \textbf{0.9955}* & \textbf0.0013 \\
# \hline
# 361253 & PySRRegressor & 0.8671 & 0.0357 \\
# 361253 & RandomForestRegressor & 0.8410 & 0.0033 \\
# 361253 & XGBRegressor & \textbf{0.9694}* & \textbf0.0010 \\
# \hline
# 361254 & PySRRegressor & 0.9298 & 0.0027 \\
# 361254 & RandomForestRegressor & \textbf{0.9795}* & \textbf0.0013 \\
# 361254 & XGBRegressor & \textbf{0.9839}* & \textbf0.0010 \\
# \hline
# 361255 & PySRRegressor & 0.6843 & 0.0212 \\
# 361255 & RandomForestRegressor & \textbf{0.8235}* & \textbf0.0146 \\
# 361255 & XGBRegressor & \textbf{0.8343}* & \textbf0.0154 \\
# \hline
# 361256 & PySRRegressor & 0.9714 & 0.0087 \\
# 361256 & RandomForestRegressor & \textbf{0.9820}* & \textbf0.0050 \\
# 361256 & XGBRegressor & \textbf{0.9841}* & \textbf0.0034 \\
# \hline
# 361257 & PySRRegressor & 0.9601 & 0.0110 \\
# 361257 & RandomForestRegressor & \textbf{0.9821}* & \textbf0.0009 \\
# 361257 & XGBRegressor & \textbf{0.9798}* & \textbf0.0014 \\
# \hline
# 361258 & PySRRegressor & 0.6304 & 0.0297 \\
# 361258 & RandomForestRegressor & \textbf{0.7246}* & \textbf0.0146 \\
# 361258 & XGBRegressor & \textbf{0.7968}* & \textbf0.0162 \\
# \hline
# 361259 & PySRRegressor & \textbf{0.6642}* & \textbf0.0165 \\
# 361259 & RandomForestRegressor & \textbf{0.6429}* & \textbf0.0200 \\
# 361259 & XGBRegressor & 0.5826 & 0.0234 \\
# \hline
# 361260 & PySRRegressor & 0.8022 & 0.0308 \\
# 361260 & RandomForestRegressor & \textbf{0.9127}* & \textbf0.0116 \\
# 361260 & XGBRegressor & \textbf{0.9171}* & \textbf0.0137 \\
# \hline
# 361261 & PySRRegressor & \textbf{0.2846}* & \textbf0.0430 \\
# 361261 & RandomForestRegressor & \textbf{0.1922}* & \textbf0.0434 \\
# 361261 & XGBRegressor & 0.1745 & 0.0344 \\
# \hline
# 361264 & PySRRegressor & \textbf{0.6484}* & \textbf0.6808 \\
# 361264 & RandomForestRegressor & 0.7353 & 0.2248 \\
# 361264 & XGBRegressor & \textbf{0.8018}* & \textbf0.2702 \\
# \hline
# 361266 & PySRRegressor & 0.7835 & 0.0511 \\
# 361266 & RandomForestRegressor & \textbf{0.8758}* & \textbf0.0433 \\
# 361266 & XGBRegressor & \textbf{0.8744}* & \textbf0.0482 \\
# \hline
# 361267 & PySRRegressor & \textbf{0.7483}* & \textbf0.2359 \\
# 361267 & RandomForestRegressor & 0.6353 & 0.2298 \\
# 361267 & XGBRegressor & 0.4516 & 0.4042 \\
# \hline
# 361268 & PySRRegressor & 0.7219 & 0.0455 \\
# 361268 & RandomForestRegressor & \textbf{0.9974}* & \textbf0.0003 \\
# 361268 & XGBRegressor & \textbf{0.9995}* & \textbf0.0000 \\
# \hline
# 361269 & PySRRegressor & \textbf{0.3877}* & \textbf0.0122 \\
# 361269 & RandomForestRegressor & \textbf{0.3217}* & \textbf0.0184 \\
# 361269 & XGBRegressor & 0.2195 & 0.0219 \\
# \hline
# 361272 & PySRRegressor & \textbf{0.7783}* & \textbf0.0296 \\
# 361272 & RandomForestRegressor & \textbf{0.7736}* & \textbf0.0342 \\
# 361272 & XGBRegressor & 0.7522 & 0.0313 \\
# \hline
# 361616 & PySRRegressor & \textbf{0.9477}* & \textbf0.0040 \\
# 361616 & RandomForestRegressor & 0.9283 & 0.0077 \\
# 361616 & XGBRegressor & 0.9275 & 0.0051 \\
# \hline
# 361617 & PySRRegressor & 0.9858 & 0.0048 \\
# 361617 & RandomForestRegressor & \textbf{0.9979}* & \textbf0.0009 \\
# 361617 & XGBRegressor & \textbf{0.9990}* & \textbf0.0005 \\
# \hline
# 361618 & PySRRegressor & \textbf{-0.0577}* & \textbf0.1615 \\
# 361618 & RandomForestRegressor & \textbf{-2.4559}* & \textbf2.9986 \\
# 361618 & XGBRegressor & -10.9977 & 16.4520 \\
# \hline
# 361619 & PySRRegressor & \textbf{0.2738}* & \textbf0.1195 \\
# 361619 & RandomForestRegressor & \textbf{0.2576}* & \textbf0.1653 \\
# 361619 & XGBRegressor & 0.1668 & 0.1864 \\
# \hline
# 361621 & PySRRegressor & 0.6193 & 0.0562 \\
# 361621 & RandomForestRegressor & 0.6213 & 0.0596 \\
# 361621 & XGBRegressor & 0.5840 & 0.0676 \\
# \hline
# 361622 & PySRRegressor & 0.9264 & 0.0263 \\
# 361622 & RandomForestRegressor & 0.9385 & 0.0239 \\
# 361622 & XGBRegressor & 0.9322 & 0.0190 \\
# \hline
# 361623 & PySRRegressor & 0.6432 & 0.0290 \\
# 361623 & RandomForestRegressor & 0.6629 & 0.0638 \\
# 361623 & XGBRegressor & 0.6828 & 0.0482 \\
# \hline
# \hline
# \end{tabular}

# %%
# ok, but actually what about a nice Excel spreadsheet?
# first, let's read a file with all the task details
df_tasks = pd.read_csv(task_details_file)

# and now we are going to create a dictionary that will be later converted to a DataFrame
results_dict = {
    'task_id' : [],
    'dataset_name' : [],
    'target_name' : [],
    'n_samples' : [],
    'n_features' : [],
    'missing_data' : [],
    'categorical_features' : [],
    'R2_PySRRegressor' : [],
    'R2_RandomForestRegressor' : [],
    'R2_XGBRegressor' : [],
}

# copy all the other columns from the df_tasks DataFrame
for column in results_dict.keys() :
    if not column.startswith('R2_') :
        results_dict[column] = df_tasks[column].tolist()

# rewrite the R2 scores for each algorithm
for task in tasks:
    for algorithm in algorithms:

        results_dict[f'R2_{algorithm}'].append("%.4f +/- %.4f" %
                                               (r2_results[task][algorithm]['mean'], r2_results[task][algorithm]['stdev']))
        
# and now we can create a DataFrame from the dictionary
df_results = pd.DataFrame(results_dict)

# color the cells, marking the significant best algorithms for each task
def highlight_best_algorithms(row) :
    task = row['task_id']
    best_algorithms = significant_best_algorithms.get(task, [])
    # col[3:] is used to skip the 'R2_' prefix, so it's the name of the algorithm
    # #e6ffe6 is a very light green color
    return [
        'background-color: #e6ffe6' if col.startswith('R2_') and col[3:] in best_algorithms else ''
        for col in row.index
    ]

# apply the highlighting function to the R2 columns
r2_columns = [f'R2_{alg}' for alg in algorithms]
df_results = df_results.style.apply(highlight_best_algorithms, axis=1)

# finally, save to Excel
df_results.to_excel("../results_server/analysis_openml_ctr23_statistics_mu50_results.xlsx", index=False)
